# %%
#imports
import pandas as pd
import plotly.express as px
import os

# %%
#file path
os.path
# Out:
# <module 'posixpath' from '/home/ubuntu/test/venv/lib/python3.6/posixpath.py'>

# %%
# reading data
df = pd.read_csv('../data_pub/data.csv', index_col=0)
df.head()
# Out:
#               ROAD NAME                geo_loc  machine_vision_prediction  \
# num
# I         AQUEDUCT LANE  41.039262, -73.866576                   8.143537
# 2     ARDSLEY AVE. EAST  41.025517, -73.866235                   2.710748
# 3    ARDSLEY AVE. WEST*  41.025593, -73.872857                   7.368577
# 4         BARBARA LANE*  41.042897, -73.854404                   7.368577
# 5       BEECHWOOD LANE*  41.027831, -73.865263                   6.667364
#
#      LENGTH\n(FT)  AVERAGE WIDTH (FT)  AREA (SF)  AREA (SY)  Year RESURFACED  \
# num
# I           215.0                21.0     4515.0     501.67           1993.0
# 2           885.0                20.0    17700.0    1966.67           1994.0
# 3          2764.0                20.0    55280.0    6142.22           1992.0
# 4           591.0                23.0    13593.0    1510.33           2009.0
# 5          1636.0                24.0    39264.0    4362.67           2001.0
#
#      Pavement Rate Total  Pavement Rate Overall   Latitude  Longitude  \
# num
# I                   9.35                    9.0  41.039262 -73.866576
# 2                   4.50                    5.0  41.025517 -73.866235
# 3                   6.80                    7.0  41.025593 -73.872857
# 4                   8.30                    8.0  41.042897 -73.854404
# 5                   8.30                    8.0  41.027831 -73.865263
#
#                       coords                              geometry
# num
# I    (-73.866576, 41.039262)  POINT (-73.86657599999999 41.039262)
# 2    (-73.866235, 41.025517)          POINT (-73.866235 41.025517)
# 3    (-73.872857, 41.025593)          POINT (-73.872857 41.025593)
# 4    (-73.854404, 41.042897)          POINT (-73.854404 41.042897)
# 5    (-73.865263, 41.027831)          POINT (-73.865263 41.027831)

# %%
# process data
df['PCI'] = ['good' if (x >= 7) else 'fine' if (x >= 5 and x <7) else 'poor' for x in df['Pavement Rate Total']]
df.head()
# Out:
#               ROAD NAME                geo_loc  machine_vision_prediction  \
# num
# I         AQUEDUCT LANE  41.039262, -73.866576                   8.143537
# 2     ARDSLEY AVE. EAST  41.025517, -73.866235                   2.710748
# 3    ARDSLEY AVE. WEST*  41.025593, -73.872857                   7.368577
# 4         BARBARA LANE*  41.042897, -73.854404                   7.368577
# 5       BEECHWOOD LANE*  41.027831, -73.865263                   6.667364
#
#      LENGTH\n(FT)  AVERAGE WIDTH (FT)  AREA (SF)  AREA (SY)  Year RESURFACED  \
# num
# I           215.0                21.0     4515.0     501.67           1993.0
# 2           885.0                20.0    17700.0    1966.67           1994.0
# 3          2764.0                20.0    55280.0    6142.22           1992.0
# 4           591.0                23.0    13593.0    1510.33           2009.0
# 5          1636.0                24.0    39264.0    4362.67           2001.0
#
#      Pavement Rate Total  Pavement Rate Overall   Latitude  Longitude  \
# num
# I                   9.35                    9.0  41.039262 -73.866576
# 2                   4.50                    5.0  41.025517 -73.866235
# 3                   6.80                    7.0  41.025593 -73.872857
# 4                   8.30                    8.0  41.042897 -73.854404
# 5                   8.30                    8.0  41.027831 -73.865263
#
#                       coords                              geometry   PCI
# num
# I    (-73.866576, 41.039262)  POINT (-73.86657599999999 41.039262)  good
[3.659126937665392, 8.3], [6.667363986135461, 6.9], [2.9958397532827163, 8.3], [8.143536762323636, 7.65], [5.458775937413701, 5.85], [7.368576777701835, 4.15], [6.667363986135461, 5.1], [3.3109149705429815, 6.9], [5.458775937413701, 8.95], [6.032880414320754, 5.85], [3.659126937665392, 6.9], [2.219372675474458, 7.55], [7.368576777701835, 4.8], [4.4692677341226865, 4.15], [6.032880414320754, 3.5], [4.4692677341226865, 3.5], [6.667363986135461, 7.55], [5.458775937413701, 6.9], [4.043960677054994, 6.6], [4.043960677054994, 6.9], [4.939304724846237, 5.1], [4.4692677341226865, 6.8], [3.659126937665392, 6.9], [7.368576777701835, 6.5431578947368445], [7.368576777701835, 6.6], [5.458775937413701, 3.4], [7.368576777701835, 5.85], [5.458775937413701, 8.95], [8.143536762323636, 7.65]], "hovertemplate": "<b>%{hovertext}</b><br><br>AVERAGE WIDTH (FT)=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<br>machine_vision_prediction=%{marker.color}<br>Pavement Rate Total=%{customdata[1]}<extra></extra>", "hovertext": ["AQUEDUCT LANE", "ARDSLEY AVE. EAST", "ARDSLEY AVE. WEST*", "BARBARA LANE*", "BEECHWOOD LANE*", "BELMONT DRIVE NORTH", "BELMONT DRIVE SOUTH", "BERTHA PLACE", "BRIDGE STREET", "BROOK PLACE", "BUCKHOUTSTREET  NORTH", "BUCKHOUT STREET SOUTH", "BUTTERWOOD EAST*", "BUTTERWOOD WEST*", "CARLA LANE*", "CASTLE ROAD*", "CEDAR LAWN ROAD", "CENTER STREET", "CINDY LANE", "CIRCLE DRIVE", "CLIFfON  PLACE", "COTTONET STREET NORTH", "COTTONET STREET SOUTH", "CROTON PLACE", "CYRUS FIELD ROAD (0-3,200 ft.)", "CYRUS FIELD ROAD (3,200-5,744 ft.)", "DEARMAN STREET NORTH", "DEARMAN STREET SOUTH", "DEEP HOLLOW CLOSE", "DOGWOOD LANE*", "DOWS LANE", "DUNHAM PLACE*", "DUTCHER STREET NORTH", "DUTCHER STREET SOUTH", "EAST CLINTON AVE.", "EAST SUNNYSIDE LANE", "ECKAR STREET NORTH", "ECKAR STREET SOUTH", "ERIE STREET", "EMORY ROAD", "FARGO LANE", "FERRIS STREET NORTH", "FERRIS STREET SOUTH", "FIELDPOINT DRIVE (0-800 ft.)", "FIELDPOINT DRIVE (800-4,500 ft.)",  ...

# %%
# local deploy
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=fig)
])

app.run_server(debug=True, use_reloader=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-f1ca6eb2b7fb> in <module>
#       1 # local deploy
# ----> 2 import dash
#       3 import dash_core_components as dcc
#       4 import dash_html_components as html
#       5
#
# ModuleNotFoundError: No module named 'dash'

# %%
#server deploy
#flask run -h localhost -p 8050

import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=fig, id='sail-routes')
])

app.run_server(host="0.0.0.0", port = 8050)
# Out:
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8050/ (Press CTRL+C to quit)

# %%
def run_server(self, 
                port=8050, 
                debug=False, 
                threaded=True, 
                **flask_run_options): 
    self.server.run(port=port, debug=debug, **flask_run_options)
